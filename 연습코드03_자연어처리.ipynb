# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/dataset/covid19_tweets.csv")
df
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 2              Time4fisticuffs            Pewee Valley, KY
# 3                  ethel mertz        Stuck in the Middle
# 4                     DIPR-J&K           Jammu and Kashmir
# ...                        ...                         ...
# 179103  AJIMATI AbdulRahman O.             Ilorin, Nigeria
# 179104                   Jason                     Ontario
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179106           Gary DelPonte               New York City
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...

# %%
df.drop(['is_retweet',"source","user_created"],inplace = True, axis = 1)
df
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 2              Time4fisticuffs            Pewee Valley, KY
# 3                  ethel mertz        Stuck in the Middle
# 4                     DIPR-J&K           Jammu and Kashmir
# ...                        ...                         ...
# 179103  AJIMATI AbdulRahman O.             Ilorin, Nigeria
# 179104                   Jason                     Ontario
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179106           Gary DelPonte               New York City
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  user_followers  \
# 0       wednesday addams as a disney princess keepin i...             624
# 1       Husband, Father, Columnist & Commentator. Auth...            2253
# ...

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
from nltk.corpus import subjectivity
import matplotlib.pyplot as plt
import re

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\medici\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def text_cleaner(text) :
    text = re.sub(r"\n"," ",text)
    text = re.sub(r"\t"," ",text)
    text = re.sub(r"\r"," ",text)
    text = re.sub(r"(@)|(#)|(RT[\s]+)|(https?:\/\/\S+)|([^a-zA-Z0-9 -])", "", text)
    text = text.strip(" ")
    return text

def Covid_or_Coronavirus_remover(text) :
    text = re.sub(r"((Covid)|(COVID)|(covid)|(Corona)|(corona)|(CORONA))+", "",text)
    text = re.sub(r"((Covid)|(COVID)|(covid)|(Corona)|(corona)|(CORONA))[A-Za-z0-9]+", "",text)
    text = text.strip(" ")
    return text

def hashtag_collector(text) :
    list_of_hashtags = re.findall(r"#[A-Za-z0-9\-\.\_]+",text,re.DOTALL)
    if(list_of_hashtags != None) :
        list_of_hashtags = [word.replace('#', '') for word in list_of_hashtags]
        list_of_hashtags = [word.replace('.', '') for word in list_of_hashtags]
        list_of_hashtags = [word.upper() for word in list_of_hashtags]
    return list_of_hashtags

def at_collector(text) :
    list_of_ats = re.findall(r"@[A-Za-z0-9\-\.\_]+",text,re.DOTALL)
    if(list_of_ats != None) :
        list_of_ats = [name.replace('@', '') for name in list_of_ats]
    return list_of_ats

def compound_sentiment_score(tweet):
    VaderSent = SIA()
    Overall_sentiment = VaderSent.polarity_scores(tweet)
    return Overall_sentiment

def getSubjectivity(tweet):
    return TextBlob.subjectivity(tweet)

def getPolarity (tweet):
    return TextBlob.polarity(tweet)

def doAnalysis(score) :
    return 'Neutral' if (score == 0) else ('Negative' if (score < 0) else 'Positive')

# %%
test_str1 = 'Corona19 Virus news descripcion'
Covid_or_Coronavirus_remover(test_str1)
# Out:
# '19 Virus news descripcion'

# %%
test_str2 = 'CoronaCorona19Virus news descripcion'
Covid_or_Coronavirus_remover(test_str2)
# Out:
# 'news descripcion'

# %%
re.findall(r"@[A-Za-z0-9\-\.\_]+",df['text'][2],re.DOTALL)
# Out:
# ['@diane3443', '@wdunlap', '@realDonaldTrump']

# %%
#re.DOTALL의 용도
text_reall = '''이런 장문의 엔터가 들어간
글을 re.all은 연결해서 하나로 묶어줍니다.
re.alll을 쓰지 않으면 각 줄마다 따로
구분되어 찾아집니다. 그럴 경우 단어가
잘려서 안찾아지거나 사용자가 보기 어려운
형태로 저장될 수 있습니다.'''

# %%
re.findall(r".+",text_reall, re.DOTALL)
# Out:
# ['이런 장문의 엔터가 들어간',
#  '글을 re.all은 연결해서 하나로 묶어줍니다.',
#  're.alll을 쓰지 않으면 각 줄마다 따로',
#  '구분되어 찾아집니다. 그럴 경우 단어가',
#  '잘려서 안찾아지거나 사용자가 보기 어려운',
#  '형태로 저장될 수 있습니다.']
