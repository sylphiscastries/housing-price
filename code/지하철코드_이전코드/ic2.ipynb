# %%
from haversine import haversine, Unit
from geopy.geocoders import Nominatim

import numpy as np
import pandas as pd
import os
import re

# %%
ic2 = pd.read_excel('data/역_인천2호선.xlsx', header=None)
del ic2[0]
ic2.dropna(axis=0, inplace=True)
address = ic2[2]
address
# Out:
# 1            경기도 파주시 문산읍 문산역로 94
# 2            경기도 파주시 파주읍 주라위길 38
# 3            경기도 파주시 월롱면 통일로 980
# 4                경기도 파주시 새꽃로 193
# 5               경기도 파주시 운정역길 368
# 6                경기도 파주시 소리천로 10
# 7           경기도 고양시 일산서구 경의로 856
# 8           경기도 고양시 일산서구 경의로 672
# 9           경기도 고양시 일산동구 경의로 486
# 10          경기도 고양시 일산동구 경의로 318
# 11          경기도 고양시 일산동구 경의로 160
# 12    경기도 고양시 덕양구 대주로107번길 71-81
# 13            경기도 고양시 덕양구 토당로 35
# 14           경기도 고양시 덕양구 소원로 102
# 15           경기도 고양시 덕양구 소원로 202
# 16            경기도 고양시 덕양구 화랑로 53
# 17           서울특별시 은평구 수색로 261-1
# 20            서울특별시 서대문구 신촌역로 30
# 21             서울특별시 서대문구 수색로 27
# 23             서울특별시 마포구 서강로 118
# 28            서울특별시 용산구 서빙고로 238
# 29        서울특별시 용산구 독서당로6길 12-13
# 31            서울특별시 성동구 고산자로 123
# 35              서울특별시 중랑구 중랑역로 9
# 37        서울특별시 중랑구 망우로55길 11-10
# 38             서울특별시 중랑구 송림길 147
# 39        경기도 구리시 건원대로34번길 32-29
# 40              경기도 남양주시 경춘로 433
# ...

# %%
geo_local = Nominatim(user_agent='South Korea') # 지역선택

def geocoding(address): 
    geo = geo_local.geocode(address)
    x_y = [geo.latitude, geo.longitude]
    return x_y

latitude = []
longitude = []
exception_addr = []

for i in address:
    try:
        latitude.append(geocoding(i)[0])
        longitude.append(geocoding(i)[1])
    except:
        latitude.append(i)
        longitude.append(i)
        exception_addr.append(i)

address_df = pd.DataFrame({'역명':ic2[1], '위도':latitude,'경도':longitude})
address_df
# Out:
#          역명                          위도                          경도
# 1        문산                   37.854429                  126.787854
# 2        파주                   37.813878                  126.800624
# 3        월롱                   37.768357                  126.792741
# 4        금촌                   37.764122                  126.771642
# 5        운정                   37.722567                  126.766019
# 6        야당                   37.712967                  126.761523
# 7        탄현                   37.696383                  126.759873
# 8        일산                   37.696383                  126.759873
# 9        풍산                   37.662253                  126.791288
# 10       백마                   37.662253                  126.791288
# 11       곡산                   37.662253                  126.791288
# 12       대곡  경기도 고양시 덕양구 대주로107번길 71-81  경기도 고양시 덕양구 대주로107번길 71-81
# 13       능곡                   37.619063                  126.821838
# ...

# %%
address_df.to_excel('data/ic2.xlsx')
